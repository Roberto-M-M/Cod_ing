# %%
import pandas as pd
url = "https://raw.githubusercontent.com/Roberto-M-M/Poryecto_ing/main/fish-consumption-vs-gdp-per-capita.csv"
datos_csv = pd.read_csv(url, encoding='latin1')
datos_csv
# Out:
#             Entity      Code  Year  \
# 0         Abkhazia  OWID_ABK  2015
# 1      Afghanistan       AFG  1961
# 2      Afghanistan       AFG  1962
# 3      Afghanistan       AFG  1963
# 4      Afghanistan       AFG  1964
# ...            ...       ...   ...
# 60499     Zimbabwe       ZWE  1956
# 60500     Zimbabwe       ZWE  1957
# 60501     Zimbabwe       ZWE  1958
# 60502     Zimbabwe       ZWE  1959
# 60503     Zimbabwe       ZWE  1960
#
#        Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita  \
# 0                                                    NaN
# 1                                               0.030559
# 2                                               0.030578
# 3                                               0.030598
# 4                                               0.030614
# ...                                                  ...
# 60499                                                NaN
# ...

# %%
datos_csv.isna().sum() #datos faltantes
# Out:
# Entity                                                                                                         0
# Code                                                                                                        5485
# Year                                                                                                           0
# Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita    47912
# GDP per capita, PPP (constant 2017 international $)                                                        54158
# Population (historical estimates)                                                                           2252
# Continent                                                                                                  60219
# dtype: int64

# %%
datos_csv_url_clean = datos_csv[['Entity','Code','Year', 'Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita', 
                                     'GDP per capita, PPP (constant 2017 international $)','Population (historical estimates)',
                                     'Continent']].dropna(axis = 0, how = 'any')  #drop rows with any missing values in them
print(datos_csv_url_clean.isna().sum())
print(len(datos_csv_url_clean))
datos_csv_url_clean
# Out:
# Entity                                                                                                     0
# Code                                                                                                       0
# Year                                                                                                       0
# Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita    0
# GDP per capita, PPP (constant 2017 international $)                                                        0
# Population (historical estimates)                                                                          0
# Continent                                                                                                  0
# dtype: int64
# 171
#                     Entity Code  Year  \
# 55             Afghanistan  AFG  2015
# 711                Albania  ALB  2015
# 970                Algeria  DZA  2015
# ...

# %%
datos_csv_url_clean.isna().sum() #datos faltantes
# Out:
# Entity                                                                                                     0
# Code                                                                                                       0
# Year                                                                                                       0
# Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita    0
# GDP per capita, PPP (constant 2017 international $)                                                        0
# Population (historical estimates)                                                                          0
# Continent                                                                                                  0
# dtype: int64

# %%
datos_csv_url_clean
# Out:
#                     Entity Code  Year  \
# 55             Afghanistan  AFG  2015
# 711                Albania  ALB  2015
# 970                Algeria  DZA  2015
# 1663                Angola  AGO  2015
# 2047   Antigua and Barbuda  ATG  2015
# ...                    ...  ...   ...
# 57752           Uzbekistan  UZB  2015
# 58042              Vanuatu  VUT  2015
# 58752              Vietnam  VNM  2015
# 60039               Zambia  ZMB  2015
# 60299             Zimbabwe  ZWE  2015
#
#        Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita  \
# 55                                              0.210000
# 711                                             8.369994
# 970                                             4.170000
# 1663                                           20.189999
# 2047                                           55.158962
# ...                                                  ...
# ...

# %%
datos_csv_url_clean.nunique()
# Out:
# Entity                                                                                                     171
# Code                                                                                                       171
# Year                                                                                                         1
# Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita    171
# GDP per capita, PPP (constant 2017 international $)                                                        171
# Population (historical estimates)                                                                          171
# Continent                                                                                                    6
# dtype: int64

# %%
datos_csv_url_clean[datos_csv_url_clean.duplicated(subset = ['Code','Continent'],keep=False)].sort_values('Continent')
# Out:
# Empty DataFrame
# Columns: [Entity, Code, Year, Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita, GDP per capita, PPP (constant 2017 international $), Population (historical estimates), Continent]
# Index: []

# %% [raw]
# Como se puede apresioar no hay datos duplicados.

# %%
datos_csv_url_clean['Code'] = datos_csv_url_clean['Code'].astype('category')
datos_csv_url_clean.dtypes
# Out:
# Entity                                                                                                       object
# Code                                                                                                       category
# Year                                                                                                          int64
# Fish and seafood | 00002960 || Food available for consumption | 0645pc || kilograms per year per capita     float64
# GDP per capita, PPP (constant 2017 international $)                                                         float64
# Population (historical estimates)                                                                           float64
# Continent                                                                                                    object
# dtype: object

# %%
datos_csv_url_clean.to_csv('Datos_procesados_soccer.csv', encoding='utf-8-sig')
